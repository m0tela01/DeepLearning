# %%
import perceptron as michael
import random
import time
import os
import math
import numpy as np
import re
import sys
import pandas as pd
import datetime
import warnings
warnings.filterwarnings('ignore')
from matplotlib import pyplot as plt
import tensorflow as tf
import keras
from keras import models, layers, losses, metrics, optimizers
from keras.callbacks import TensorBoard
# Out:
# Using TensorFlow backend.

# %%
import seaborn as sns
sns.set
sns.set_style("darkgrid")

# %% [markdown]
# # (1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![hw1-1.png](attachment:hw1-1.png)

# %% [markdown]
# # (2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![hw1-2.png](attachment:hw1-2.png)

# %% [markdown]
# # (3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## a) The network has three layers where the first is the input layer, the second is a hidden layer with sigmoid as the activation function, and the last is the output layer (presumably also with sigmoid activation). Each layer is dense or fully connected. There is no bias added to any of the layers/nodes. This is a very simple network. This is a small MLP. There is no momentum or learning rate specified.

# %% [markdown]
# ## b) computing output & error

# %%
inputNode1, inputNode2, targetNode = 1, 1, 0
inputWeights1 = [0.8, 0.4, 0.3]
inputWeights2 = [0.2, 0.9, 0.5]
hiddenWeights = [0.3, 0.5, 0.9]

# %% [markdown]
# #### Predicted Hidden Node 1 & error

# %%
p_hiddenNode1 = michael.sigmoid((inputNode1 * inputWeights1[0]) 
                                + (inputNode2 * inputWeights2[0]))
h1Error = michael.MSE(hiddenWeights[0], p_hiddenNode1, 2)
p_hiddenNode1, h1Error
# Out:
# (0.7310585786300049, 0.09290574910526006)

# %% [markdown]
# #### Predicted Hidden Node 2 & error

# %%
p_hiddenNode2 = michael.sigmoid((inputNode1 * inputWeights1[1]) 
                                + (inputNode2 * inputWeights2[1]))
h2Error = michael.MSE(hiddenWeights[1], p_hiddenNode2, 2)
p_hiddenNode2, h2Error
# Out:
# (0.7858349830425586, 0.040850818765469886)

# %% [markdown]
# #### Predicted Hidden Node 3 & error

# %%
p_hiddenNode3 = michael.sigmoid((inputNode1 * inputWeights1[2]) 
                              + (inputNode2 * inputWeights1[2]))
h3Error = michael.MSE(hiddenWeights[2], p_hiddenNode3, 2)
p_hiddenNode3, h3Error
# Out:
# (0.6456563062257954, 0.03234535728135319)

# %% [markdown]
# ### Predicted Output and Error

# %%
p_output = michael.sigmoid((p_hiddenNode1 * hiddenWeights[0]) 
                           + (p_hiddenNode2 * hiddenWeights[1]) 
                           + (p_hiddenNode3 * hiddenWeights[2]))
outputError = michael.MSE(targetNode, p_output, 2)
p_output, outputError
# Out:
# (0.7673353425710626, 0.294401763979325)

# %% [markdown]
# ## c) computing 2 epochs
# - already computed the predicted hidden nodes, the predicted output, and each of the corresponding errors for the first iteration
#     - compute the gradiant then compute another forward pass followed by another back prop
#     - at the end of the second back prop the second epoch is over

# %% [markdown]
# #### arbitrary learning rate

# %%
learningRate = 0.1

# %%
### just for reference
# inputNode1, inputNode2, targetNode = 1, 1, 0
# inputWeights1 = [0.8, 0.4, 0.3]
# inputWeights2 = [0.2, 0.9, 0.5]
# hiddenWeights = [0.3, 0.5, 0.9]

# %% [markdown]
# ### ** Epoch 1 **

# %% [markdown]
# #### from above - feed forward (forward propagation) to hidden layer

# %%
p_hiddenNodes = [p_hiddenNode1, p_hiddenNode2, p_hiddenNode3]
hiddenError = [h2Error, h2Error, h3Error]

# %% [markdown]
# ### Back propagating

# %% [markdown]
# ##### weights connected to output layer

# %%
################## hidden_W1 -> output_1
### derivative of error on predicted output
dError = michael.dMSE(targetNode, p_output)

### derivative of activation on predicted output
dActivationOutput = michael.dSigmoid(p_output)

### compute gradiant wrt weight_i
gradiant = dError * dActivationOutput * p_hiddenNodes[0]

### update weight_i
new_hidden1 = hiddenWeights[0] - (learningRate * gradiant)


################## hidden_W2 -> output_1
gradiant = dError * dActivationOutput * p_hiddenNodes[1]
new_hidden2 = hiddenWeights[1] - (learningRate * gradiant)


################## hidden_W3 -> output_1
gradiant = dError * dActivationOutput * p_hiddenNodes[2]
new_hidden3 = hiddenWeights[2] - (learningRate * gradiant)


newHiddenWeights = [new_hidden1, new_hidden2, new_hidden3]
newHiddenWeights
# Out:
# [0.28785329993086123, 0.4869431778493832, 0.8892722775866064]

# %% [markdown]
# ##### weights connected to input layer

# %%
################## input_1_W1 -> hidden_1##################
### derivative of error on predicted output
dError = michael.dMSE(targetNode, p_output)

### derivative of activation on predicted output
dActivationOutput = michael.dSigmoid(p_output)

### derivative of activation on predicted hiddenNode_i
dActivationHidden = michael.dSigmoid(p_hiddenNodes[0])

### compute gradiant wrt input weight_i and weight_hi connected to output
gradiant = dError * dActivationOutput * hiddenWeights[0] * dActivationHidden * inputWeights1[0]

### update weight_i for input_j
new_input11 = inputWeights1[0] - (learningRate * gradiant)


################## input_1_W2 -> hidden_2
dActivationHidden = michael.dSigmoid(p_hiddenNodes[1])
gradiant = dError * dActivationOutput * hiddenWeights[1] * dActivationHidden * inputWeights1[1]
new_input12 = inputWeights1[1] - (learningRate * gradiant)


################## input_1_W3 -> hidden_3
dActivationHidden = michael.dSigmoid(p_hiddenNodes[2])
gradiant = dError * dActivationOutput * hiddenWeights[2] * dActivationHidden * inputWeights1[2]
new_input13 = inputWeights1[2] - (learningRate * gradiant)

newInputWeights1 = [new_input11, new_input12, new_input13]
######################################################


################## input_2_W1 -> hidden_1##################
dActivationHidden = michael.dSigmoid(p_hiddenNodes[1])
gradiant = dError * dActivationOutput * hiddenWeights[0] * dActivationHidden * inputWeights2[0]
new_input21 = inputWeights2[0] - (learningRate * gradiant)


################## input_2_W2 -> hidden_2
dActivationHidden = michael.dSigmoid(p_hiddenNodes[2])
gradiant = dError * dActivationOutput * hiddenWeights[1] * dActivationHidden * inputWeights2[1]
new_input22 = inputWeights2[1] - (learningRate * gradiant)


################## input_1_W3 -> hidden_3
dActivationHidden = michael.dSigmoid(p_hiddenNodes[2])
gradiant = dError * dActivationOutput * hiddenWeights[2] * dActivationHidden * inputWeights2[2]
new_input23 = inputWeights2[2] - (learningRate * gradiant)

newInputWeights2 = [new_input21, new_input22, new_input23]
######################################################

print(newInputWeights1)
print(newInputWeights2)
# Out:
# [0.7991252609801877, 0.3992853633426242, 0.2989876898595625]
# [0.19978560900278727, 0.8983128164326042, 0.49831281643260417]

# %% [markdown]
# ### update weights

# %%
inputWeights1 = newInputWeights1 #[0.8, 0.4, 0.3]
inputWeights2 = newInputWeights2 #[0.2, 0.9, 0.5]
hiddenWeights = newHiddenWeights #[0.3, 0.5, 0.9]

# %% [markdown]
# ### ** Epoch 2 **

# %% [markdown]
# #### forward propagate

# %%
### hidden node 1
p_hiddenNode1 = michael.sigmoid((inputNode1 * inputWeights1[0]) 
                                + (inputNode2 * inputWeights2[0]))
h1Error = michael.MSE(hiddenWeights[0], p_hiddenNode1, 2)


### hidden node 2
p_hiddenNode2 = michael.sigmoid((inputNode1 * inputWeights1[1]) 
                                + (inputNode2 * inputWeights2[1]))
h2Error = michael.MSE(hiddenWeights[1], p_hiddenNode2, 2)


### hidden node 3
p_hiddenNode3 = michael.sigmoid((inputNode1 * inputWeights1[2]) 
                              + (inputNode2 * inputWeights1[2]))
h3Error = michael.MSE(hiddenWeights[2], p_hiddenNode3, 2)


### predicted output
p_output = michael.sigmoid((p_hiddenNode1 * hiddenWeights[0]) 
                           + (p_hiddenNode2 * hiddenWeights[1]) 
                           + (p_hiddenNode3 * hiddenWeights[2]))
outputError = michael.MSE(targetNode, p_output, 2)
print(p_output, outputError)
# Out:
# 0.7625277641920128 0.290724295581835

# %% [markdown]
# ### Back propagating

# %% [markdown]
# ##### weights connected to output layer

# %%
################## hidden_W1 -> output_1
### derivative of error on predicted output
dError = michael.dMSE(targetNode, p_output)

### derivative of activation on predicted output
dActivationOutput = michael.dSigmoid(p_output)

### compute gradiant wrt weight_i
gradiant = dError * dActivationOutput * p_hiddenNodes[0]

### update weight_i
new_hidden1 = hiddenWeights[0] - (learningRate * gradiant)


################## hidden_W2 -> output_1
gradiant = dError * dActivationOutput * p_hiddenNodes[1]
new_hidden2 = hiddenWeights[1] - (learningRate * gradiant)


################## hidden_W3 -> output_1
gradiant = dError * dActivationOutput * p_hiddenNodes[2]
new_hidden3 = hiddenWeights[2] - (learningRate * gradiant)


newHiddenWeights = [new_hidden1, new_hidden2, new_hidden3]
newHiddenWeights
# Out:
# [0.27576151169570445, 0.4739453819401476, 0.8785930522060543]

# %% [markdown]
# ##### weights connected to input layer

# %%
################## input_1_W1 -> hidden_1##################
### derivative of error on predicted output
dError = michael.dMSE(targetNode, p_output)

### derivative of activation on predicted output
dActivationOutput = michael.dSigmoid(p_output)

### derivative of activation on predicted hiddenNode_i
dActivationHidden = michael.dSigmoid(p_hiddenNodes[0])

### compute gradiant wrt input weight_i and weight_hi connected to output
gradiant = dError * dActivationOutput * hiddenWeights[0] * dActivationHidden * inputWeights1[0]

### update weight_i for input_j
new_input11 = inputWeights1[0] - (learningRate * gradiant)


################## input_1_W2 -> hidden_2
dActivationHidden = michael.dSigmoid(p_hiddenNodes[1])
gradiant = dError * dActivationOutput * hiddenWeights[1] * dActivationHidden * inputWeights1[1]
new_input12 = inputWeights1[1] - (learningRate * gradiant)


################## input_1_W3 -> hidden_3
dActivationHidden = michael.dSigmoid(p_hiddenNodes[2])
gradiant = dError * dActivationOutput * hiddenWeights[2] * dActivationHidden * inputWeights1[2]
new_input13 = inputWeights1[2] - (learningRate * gradiant)

newInputWeights1 = [new_input11, new_input12, new_input13]
######################################################


################## input_2_W1 -> hidden_1##################
dActivationHidden = michael.dSigmoid(p_hiddenNodes[1])
gradiant = dError * dActivationOutput * hiddenWeights[0] * dActivationHidden * inputWeights2[0]
new_input21 = inputWeights2[0] - (learningRate * gradiant)


################## input_2_W2 -> hidden_2
dActivationHidden = michael.dSigmoid(p_hiddenNodes[2])
gradiant = dError * dActivationOutput * hiddenWeights[1] * dActivationHidden * inputWeights2[1]
new_input22 = inputWeights2[1] - (learningRate * gradiant)


################## input_1_W3 -> hidden_3
dActivationHidden = michael.dSigmoid(p_hiddenNodes[2])
gradiant = dError * dActivationOutput * hiddenWeights[2] * dActivationHidden * inputWeights2[2]
new_input23 = inputWeights2[2] - (learningRate * gradiant)

newInputWeights2 = [new_input21, new_input22, new_input23]
######################################################

print(newInputWeights1)
print(newInputWeights2)
# Out:
# [0.7982906471929707, 0.3985937725623149, 0.29799532789711003]
# [0.19958104795798365, 0.8966801858422859, 0.4966588798285168]

# %% [markdown]
# # (4)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## a) Generating random data set with variance 0.08

# %%
binary_dataset = []
variance = 0.08
std = round(math.sqrt(variance), 3)

# %% [markdown]
# ### this is the dataset for the green in 4.a

# %%
x1 = abs(np.random.normal(0, std, 1000))
y1 = abs(np.random.normal(0, std, 1000))

x2, y2 = [], []
for i, v in enumerate(x1):
    if x1[i] <= 0.25 and y1[i] <= 0.25 and len(x2) < 100:
        x2.append(x1[i])
        y2.append(y1[i])
binary_dataset.append(x2)
binary_dataset.append(y2)

fig = plt.figure(figsize=(16,16))
plt.scatter(x2,y2, c='g', s=100, alpha=0.5)
plt.plot([0,0.25], [0.25, 0.25], 'g', lw=5)
plt.plot([0.25,0.25], [0, 0.25], 'g', lw=5)

# %% [markdown]
# ### this is the dataset for the yellow in 4.a
# - ill admit it is a weird way of doing it

# %%
## top left
x1 = abs(np.random.normal(0, std, 500))
y1 = abs(np.random.normal(0, std, 500)) + 0.25

x2, y2 = [], []
for i, v in enumerate(x1):
    if x1[i] < 0.25 and y1[i] <= 0.5 and len(x2) < 33:
        x2.append(x1[i])
        y2.append(y1[i])
binary_dataset[0].extend(x2)
binary_dataset[1].extend(y2)
# plt.scatter(x2,y2)

# %%
## top right
x1 = abs(np.random.normal(0, std, 500)) + 0.25
y1 = abs(np.random.normal(0, std, 500)) + 0.25

x2, y2 = [], []
for i, v in enumerate(x1):
    if (0.25 < x1[i] <= 0.5) and (0.25 < y1[i] <= 0.5) and len(x2) < 33:
        x2.append(x1[i])
        y2.append(y1[i])
binary_dataset[0].extend(x2)
binary_dataset[1].extend(y2)
# plt.scatter(x2,y2)

# %%
## bottom right (someone has to get an extra point)
x1 = abs(np.random.normal(0, std, 500)) + 0.25
y1 = abs(np.random.normal(0, std, 500)) 

x2, y2 = [], []
for i, v in enumerate(x1):
    if x1[i] <= 0.5 and y1[i] < 0.25 and len(x2) < 34:
        x2.append(x1[i])
        y2.append(y1[i])
binary_dataset[0].extend(x2)
binary_dataset[1].extend(y2)
# plt.scatter(x2,y2)

# %%
dataset = np.transpose(binary_dataset)

fig = plt.figure(figsize=(16,16))
for i, v in enumerate(dataset):
    if dataset[i][0] < 0.25 and dataset[i][1] < 0.25:
        pass
#         plt.scatter(dataset[i][0], dataset[i][1], c='g', s=100, alpha=0.5)
    else:
        plt.scatter(dataset[i][0], dataset[i][1], c='y', s=100, alpha=0.5)
plt.plot([0,0.25], [0.25, 0.25], 'g', lw=5)
plt.plot([0.25,0.25], [0, 0.25], 'g', lw=5)

# %%
df = pd.DataFrame(dataset)
## shuffle a few times
df = df.sample(frac=1).reset_index(drop=True)
df = df.sample(frac=1).reset_index(drop=True)
df = df.sample(frac=1).reset_index(drop=True)
dataset = df.to_numpy()
df
# Out:
#             0         1
# 0    0.053321  0.176606
# 1    0.202312  0.162343
# 2    0.431360  0.000559
# 3    0.147971  0.249158
# 4    0.492042  0.228960
# ..        ...       ...
# 195  0.054272  0.091093
# 196  0.434145  0.115125
# 197  0.128727  0.164305
# 198  0.095559  0.273896
# 199  0.119096  0.221951
#
# [200 rows x 2 columns]

# %% [markdown]
# ### generate labels

# %%
labels = []
ones = []
zeros = []
for i in range(len(dataset)):
    x0, y0 = dataset[i]
    if (x0 <= 0.25) and (y0 <= 0.25):
        labels.append(1)
        ones.append(i)
    else:
        labels.append(0)
        zeros.append(i)

# %% [markdown]
# ### validate labels

# %%
fig = plt.figure(figsize=(16,16))
for i,v in enumerate(labels):
    if labels[i] == 1:
        plt.scatter(dataset[i][0], dataset[i][1], c='g', s=100, alpha=0.5)
    else:
        plt.scatter(dataset[i][0], dataset[i][1], c='y', s=100, alpha=0.5)
plt.plot([0,0.25], [0.25, 0.25], 'g', lw=5)
plt.plot([0.25,0.25], [0, 0.25], 'g', lw=5)

# %% [markdown]
# ### split training and validation sets

# %%
x_train = dataset[:160]
y_train = labels[:160]

x_val = dataset[-40:]
y_val = labels[-40:]

# %%
(x_train.shape, len(y_train)), (x_val.shape, len(y_val))
# Out:
# (((160, 2), 160), ((40, 2), 40))

# %% [markdown]
# ## For this problem I chose to use:
# - 1 hidden layer
# - relu as the activation for the input and hidden layers (because binary data: 0 or 1 as ouput)
# - sigmoid for activation in last layer (because sum of outputs does not to equal 1)
# - rmsprop (because its good for SGD)
# - binary_crossentropy for loss (because data is binary)

# %% [markdown]
# ## My model

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(2,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From c:\users\telahun\anaconda3\envs\chollet\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\users\telahun\anaconda3\envs\chollet\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\users\telahun\anaconda3\envs\chollet\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['acc'])
# Out:
# WARNING:tensorflow:From c:\users\telahun\anaconda3\envs\chollet\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From c:\users\telahun\anaconda3\envs\chollet\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From c:\users\telahun\anaconda3\envs\chollet\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
history = model.fit(x_train,
                    y_train,
                    epochs=100,
                    batch_size=16,
                    validation_data=(x_val, y_val))
# Out:
# WARNING:tensorflow:From c:\users\telahun\anaconda3\envs\chollet\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 160 samples, validate on 40 samples
# Epoch 1/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7092 - acc: 0.4562 - val_loss: 0.7015 - val_acc: 0.5500
# Epoch 2/100
# 160/160 [==============================] - 0s 113us/step - loss: 0.7000 - acc: 0.4062 - val_loss: 0.6967 - val_acc: 0.4250
# Epoch 3/100
# 160/160 [==============================] - 0s 112us/step - loss: 0.6939 - acc: 0.4250 - val_loss: 0.6917 - val_acc: 0.4250
# Epoch 4/100
# 160/160 [==============================] - 0s 269us/step - loss: 0.6868 - acc: 0.5625 - val_loss: 0.6860 - val_acc: 0.4750
# Epoch 5/100
# 160/160 [==============================] - 0s 131us/step - loss: 0.6811 - acc: 0.6125 - val_loss: 0.6820 - val_acc: 0.4750
# Epoch 6/100
# 160/160 [==============================] - 0s 112us/step - loss: 0.6771 - acc: 0.6125 - val_loss: 0.6793 - val_acc: 0.4750
# Epoch 7/100
# 160/160 [==============================] - 0s 112us/step - loss: 0.6737 - acc: 0.6500 - val_loss: 0.6767 - val_acc: 0.4750
# Epoch 8/100
# 160/160 [==============================] - 0s 112us/step - loss: 0.6703 - acc: 0.6375 - val_loss: 0.6739 - val_acc: 0.5250
# Epoch 9/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.6666 - acc: 0.6437 - val_loss: 0.6710 - val_acc: 0.5250
# Epoch 10/100
# 160/160 [==============================] - 0s 137us/step - loss: 0.6629 - acc: 0.6500 - val_loss: 0.6678 - val_acc: 0.5500
# Epoch 11/100
# 160/160 [==============================] - 0s 112us/step - loss: 0.6586 - acc: 0.6750 - val_loss: 0.6642 - val_acc: 0.6000
# Epoch 12/100
# 160/160 [==============================] - 0s 113us/step - loss: 0.6537 - acc: 0.6750 - val_loss: 0.6599 - val_acc: 0.6250
# Epoch 13/100
# 160/160 [==============================] - 0s 113us/step - loss: 0.6486 - acc: 0.6937 - val_loss: 0.6556 - val_acc: 0.6500
# Epoch 14/100
# 160/160 [==============================] - 0s 75us/step - loss: 0.6432 - acc: 0.7188 - val_loss: 0.6512 - val_acc: 0.6750
# Epoch 15/100
# 160/160 [==============================] - 0s 150us/step - loss: 0.6384 - acc: 0.7312 - val_loss: 0.6473 - val_acc: 0.6750
# Epoch 16/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.6327 - acc: 0.7375 - val_loss: 0.6427 - val_acc: 0.6750
# Epoch 17/100
# 160/160 [==============================] - 0s 131us/step - loss: 0.6273 - acc: 0.7375 - val_loss: 0.6380 - val_acc: 0.6750
# Epoch 18/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.6213 - acc: 0.7375 - val_loss: 0.6333 - val_acc: 0.7000
# Epoch 19/100
# 160/160 [==============================] - 0s 119us/step - loss: 0.6155 - acc: 0.7500 - val_loss: 0.6280 - val_acc: 0.7500
# Epoch 20/100
# 160/160 [==============================] - 0s 169us/step - loss: 0.6095 - acc: 0.7750 - val_loss: 0.6229 - val_acc: 0.7750
# Epoch 21/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.6031 - acc: 0.7875 - val_loss: 0.6176 - val_acc: 0.7750
# Epoch 22/100
# 160/160 [==============================] - 0s 169us/step - loss: 0.5965 - acc: 0.7812 - val_loss: 0.6117 - val_acc: 0.7750
# Epoch 23/100
# 160/160 [==============================] - 0s 119us/step - loss: 0.5898 - acc: 0.8187 - val_loss: 0.6060 - val_acc: 0.7500
# Epoch 24/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.5821 - acc: 0.8125 - val_loss: 0.5992 - val_acc: 0.7500
# Epoch 25/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.5750 - acc: 0.8187 - val_loss: 0.5928 - val_acc: 0.7750
# Epoch 26/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.5679 - acc: 0.8187 - val_loss: 0.5871 - val_acc: 0.7750
# Epoch 27/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.5606 - acc: 0.8438 - val_loss: 0.5808 - val_acc: 0.7750
# Epoch 28/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.5531 - acc: 0.8562 - val_loss: 0.5747 - val_acc: 0.7750
# Epoch 29/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.5450 - acc: 0.8625 - val_loss: 0.5675 - val_acc: 0.7500
# Epoch 30/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.5367 - acc: 0.8625 - val_loss: 0.5600 - val_acc: 0.7500
# Epoch 31/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.5287 - acc: 0.8688 - val_loss: 0.5537 - val_acc: 0.7500
# Epoch 32/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.5204 - acc: 0.8625 - val_loss: 0.5464 - val_acc: 0.7500
# Epoch 33/100
# 160/160 [==============================] - 0s 125us/step - loss: 0.5116 - acc: 0.8625 - val_loss: 0.5378 - val_acc: 0.7750
# Epoch 34/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.5029 - acc: 0.8812 - val_loss: 0.5308 - val_acc: 0.7750
# Epoch 35/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.4942 - acc: 0.8688 - val_loss: 0.5232 - val_acc: 0.8000
# Epoch 36/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.4854 - acc: 0.8750 - val_loss: 0.5155 - val_acc: 0.8000
# Epoch 37/100
# 160/160 [==============================] - 0s 113us/step - loss: 0.4773 - acc: 0.8750 - val_loss: 0.5083 - val_acc: 0.8000
# Epoch 38/100
# 160/160 [==============================] - 0s 119us/step - loss: 0.4686 - acc: 0.8750 - val_loss: 0.5008 - val_acc: 0.8000
# Epoch 39/100
# 160/160 [==============================] - 0s 131us/step - loss: 0.4607 - acc: 0.8688 - val_loss: 0.4936 - val_acc: 0.8000
# Epoch 40/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.4526 - acc: 0.8875 - val_loss: 0.4862 - val_acc: 0.8000
# Epoch 41/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.4450 - acc: 0.8812 - val_loss: 0.4793 - val_acc: 0.8000
# Epoch 42/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.4373 - acc: 0.9000 - val_loss: 0.4735 - val_acc: 0.8000
# Epoch 43/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.4294 - acc: 0.8938 - val_loss: 0.4666 - val_acc: 0.8000
# Epoch 44/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.4223 - acc: 0.8938 - val_loss: 0.4599 - val_acc: 0.8000
# Epoch 45/100
# 160/160 [==============================] - 0s 69us/step - loss: 0.4145 - acc: 0.9000 - val_loss: 0.4528 - val_acc: 0.8000
# Epoch 46/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.4078 - acc: 0.8938 - val_loss: 0.4467 - val_acc: 0.8000
# Epoch 47/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.4002 - acc: 0.9000 - val_loss: 0.4418 - val_acc: 0.8000
# Epoch 48/100
# 160/160 [==============================] - 0s 75us/step - loss: 0.3932 - acc: 0.9062 - val_loss: 0.4352 - val_acc: 0.8000
# Epoch 49/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.3863 - acc: 0.9062 - val_loss: 0.4283 - val_acc: 0.8250
# Epoch 50/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.3793 - acc: 0.8938 - val_loss: 0.4230 - val_acc: 0.8250
# Epoch 51/100
# 160/160 [==============================] - 0s 150us/step - loss: 0.3723 - acc: 0.8875 - val_loss: 0.4167 - val_acc: 0.8500
# Epoch 52/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.3663 - acc: 0.8938 - val_loss: 0.4113 - val_acc: 0.8500
# Epoch 53/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.3597 - acc: 0.8938 - val_loss: 0.4054 - val_acc: 0.8500
# Epoch 54/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.3527 - acc: 0.8938 - val_loss: 0.3994 - val_acc: 0.8500
# Epoch 55/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.3465 - acc: 0.9062 - val_loss: 0.3949 - val_acc: 0.8500
# Epoch 56/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.3396 - acc: 0.8938 - val_loss: 0.3904 - val_acc: 0.8500
# Epoch 57/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.3355 - acc: 0.8812 - val_loss: 0.3859 - val_acc: 0.8500
# Epoch 58/100
# 160/160 [==============================] - 0s 144us/step - loss: 0.3289 - acc: 0.9000 - val_loss: 0.3814 - val_acc: 0.8500
# Epoch 59/100
# 160/160 [==============================] - 0s 75us/step - loss: 0.3238 - acc: 0.8938 - val_loss: 0.3774 - val_acc: 0.8500
# Epoch 60/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.3185 - acc: 0.9000 - val_loss: 0.3733 - val_acc: 0.8500
# Epoch 61/100
# 160/160 [==============================] - 0s 88us/step - loss: 0.3148 - acc: 0.8938 - val_loss: 0.3688 - val_acc: 0.8500
# Epoch 62/100
# 160/160 [==============================] - 0s 125us/step - loss: 0.3099 - acc: 0.9000 - val_loss: 0.3649 - val_acc: 0.8500
# Epoch 63/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.3059 - acc: 0.9000 - val_loss: 0.3620 - val_acc: 0.8500
# Epoch 64/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.3022 - acc: 0.9062 - val_loss: 0.3585 - val_acc: 0.8500
# Epoch 65/100
# 160/160 [==============================] - 0s 112us/step - loss: 0.2971 - acc: 0.9000 - val_loss: 0.3556 - val_acc: 0.8500
# Epoch 66/100
# 160/160 [==============================] - 0s 150us/step - loss: 0.2927 - acc: 0.9000 - val_loss: 0.3515 - val_acc: 0.8500
# Epoch 67/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.2906 - acc: 0.9062 - val_loss: 0.3490 - val_acc: 0.8500
# Epoch 68/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.2854 - acc: 0.8938 - val_loss: 0.3451 - val_acc: 0.8500
# Epoch 69/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.2817 - acc: 0.9062 - val_loss: 0.3425 - val_acc: 0.8500
# Epoch 70/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.2784 - acc: 0.9125 - val_loss: 0.3400 - val_acc: 0.8500
# Epoch 71/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.2744 - acc: 0.9062 - val_loss: 0.3368 - val_acc: 0.8500
# Epoch 72/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.2704 - acc: 0.9062 - val_loss: 0.3338 - val_acc: 0.8500
# Epoch 73/100
# 160/160 [==============================] - 0s 144us/step - loss: 0.2674 - acc: 0.9000 - val_loss: 0.3310 - val_acc: 0.8500
# Epoch 74/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.2643 - acc: 0.9125 - val_loss: 0.3283 - val_acc: 0.8500
# Epoch 75/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.2622 - acc: 0.9062 - val_loss: 0.3259 - val_acc: 0.8500
# Epoch 76/100
# 160/160 [==============================] - 0s 137us/step - loss: 0.2595 - acc: 0.9125 - val_loss: 0.3243 - val_acc: 0.8500
# Epoch 77/100
# 160/160 [==============================] - 0s 88us/step - loss: 0.2567 - acc: 0.9062 - val_loss: 0.3229 - val_acc: 0.8500
# Epoch 78/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.2543 - acc: 0.9125 - val_loss: 0.3204 - val_acc: 0.8500
# Epoch 79/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.2514 - acc: 0.9187 - val_loss: 0.3191 - val_acc: 0.8500
# Epoch 80/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.2492 - acc: 0.9187 - val_loss: 0.3169 - val_acc: 0.8500
# Epoch 81/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.2480 - acc: 0.9062 - val_loss: 0.3157 - val_acc: 0.8500
# Epoch 82/100
# 160/160 [==============================] - 0s 75us/step - loss: 0.2451 - acc: 0.9187 - val_loss: 0.3137 - val_acc: 0.8500
# Epoch 83/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.2428 - acc: 0.9125 - val_loss: 0.3120 - val_acc: 0.8500
# Epoch 84/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.2406 - acc: 0.9125 - val_loss: 0.3101 - val_acc: 0.8500
# Epoch 85/100
# 160/160 [==============================] - 0s 125us/step - loss: 0.2384 - acc: 0.9062 - val_loss: 0.3083 - val_acc: 0.8500
# Epoch 86/100
# 160/160 [==============================] - 0s 125us/step - loss: 0.2361 - acc: 0.9187 - val_loss: 0.3070 - val_acc: 0.8500
# Epoch 87/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.2347 - acc: 0.9062 - val_loss: 0.3058 - val_acc: 0.8500
# Epoch 88/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.2322 - acc: 0.9125 - val_loss: 0.3040 - val_acc: 0.8500
# Epoch 89/100
# 160/160 [==============================] - 0s 113us/step - loss: 0.2306 - acc: 0.9125 - val_loss: 0.3024 - val_acc: 0.8500
# Epoch 90/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.2283 - acc: 0.9125 - val_loss: 0.3014 - val_acc: 0.8500
# Epoch 91/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.2268 - acc: 0.9125 - val_loss: 0.2997 - val_acc: 0.8500
# Epoch 92/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.2242 - acc: 0.9187 - val_loss: 0.2985 - val_acc: 0.8500
# Epoch 93/100
# 160/160 [==============================] - 0s 119us/step - loss: 0.2220 - acc: 0.9125 - val_loss: 0.2967 - val_acc: 0.8500
# Epoch 94/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.2208 - acc: 0.9125 - val_loss: 0.2953 - val_acc: 0.8500
# Epoch 95/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.2191 - acc: 0.9125 - val_loss: 0.2948 - val_acc: 0.8500
# Epoch 96/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.2177 - acc: 0.9125 - val_loss: 0.2929 - val_acc: 0.8500
# Epoch 97/100
# 160/160 [==============================] - 0s 91us/step - loss: 0.2158 - acc: 0.9125 - val_loss: 0.2915 - val_acc: 0.8500
# Epoch 98/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.2156 - acc: 0.9187 - val_loss: 0.2905 - val_acc: 0.8500
# Epoch 99/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.2124 - acc: 0.9187 - val_loss: 0.2895 - val_acc: 0.8500
# Epoch 100/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.2111 - acc: 0.9125 - val_loss: 0.2882 - val_acc: 0.8500

# %% [markdown]
# ## Evaluating the model

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
acc = history_dict['acc']
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(acc) + 1)

# acc = history_dict['acc'][-100:]
# loss_values = history_dict['loss'][-100:]
# val_loss_values = history_dict['val_loss'][-100:]
# epochs = range(200, 300)

plt.figure(figsize=(16, 10))
plt.plot(epochs, loss_values, 'r', label='Training loss')
plt.plot(epochs, val_loss_values, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

plt.figure(figsize=(16, 10))
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'g', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing

# %%
x_test, y_test = [], []
x1_test = abs(np.random.rand(5000))
y1_test = abs(np.random.rand(5000))

# x2_test, y2_test = x1_test, y1_test
x2_test, y2_test = [], []
for i, v in enumerate(x1_test):
    if x1_test[i] <= 0.5 and y1_test[i] <= 0.5 and len(x2_test) < 500:
        x2_test.append(x1_test[i])
        y2_test.append(y1_test[i])
x_test.append(x2_test)
x_test.append(y2_test)
x_test = np.transpose(x_test)

## dont need to shuffle because it is a random set of points

for i in range(len(x_test)):
    x0, y0 = x_test[i]
    if (x0 <= 0.25) and (y0 <= 0.25):
        y_test.append(1)
    else:
        y_test.append(0)
        
# plt.figure(figsize=(16,16))
# plt.scatter(x2_test, y2_test, s=100, alpha=0.5)


plt.figure(figsize=(16,16))
for i,v in enumerate(y_test):
    if y_test[i] == 1:
        plt.scatter(x_test[i][0], x_test[i][1], c='g', s=200, alpha=0.3)
        plt.scatter(x_test[i][0], x_test[i][1], s=35, alpha=0.9)
    else:
        plt.scatter(x_test[i][0], x_test[i][1], c='y', s=200, alpha=0.3)
        plt.scatter(x_test[i][0], x_test[i][1], s=35, alpha=0.9)

# %%
results = model.evaluate(x_test, y_test)
results, model.metrics_names
# Out:
# 500/500 [==============================] - 0s 18us/step
# ([0.17857835972309113, 0.9339999990463257], ['loss', 'acc'])

# %% [markdown]
# ## b) Generating random data set with variance 0.08
# ![image.png](attachment:image.png)

# %% [markdown]
# ### this is the dataset for the green in 4.b

# %%
binary_dataset = []

# %%
x1 = abs(np.random.normal(0, std, 500))
y1 = abs(np.random.normal(0, std, 500))

radiusSquared = math.pow(0.425, 2)
x2, y2 = [], []
for i, v in enumerate(x1):
    locationRelativeToCircle = math.pow((x1[i] - 0.08), 2) + math.pow((y1[i] - 0.08), 2)
    if (locationRelativeToCircle < radiusSquared) and len(x2) < 100:
        x2.append(x1[i])
        y2.append(y1[i])
binary_dataset.append(x2)
binary_dataset.append(y2)


fig = plt.figure(figsize=(16,16))
fig = plt.gcf()
ax = fig.gca()
circle1 = plt.Circle((0.08, 0.08), 0.425, color='g', alpha=0.4)
ax.add_artist(circle1)
plt.scatter(x2, y2, c='g', s=100, alpha=0.5)

# %% [markdown]
# ### this is the dataset for the yellow in 4.b

# %%
## top right
x1 = abs(np.random.normal(0, std, 15000))
y1 = abs(np.random.normal(0, std, 15000))

radiusSquared = math.pow(0.425, 2)
x2, y2 = [], []
for i, v in enumerate(x1):
    locationRelativeToCircle = math.pow((x1[i] - 0.08), 2) + math.pow((y1[i] - 0.08), 2)
    
    if (locationRelativeToCircle > radiusSquared) \
        and (x1[i] <= 0.5) and (y1[i] <= 0.5) and len(x2) < 100:
        x2.append(x1[i])
        y2.append(y1[i])
binary_dataset[0].extend(x2)
binary_dataset[1].extend(y2)


fig = plt.figure(figsize=(16,16))
fig = plt.gcf()
ax = fig.gca()
circle1 = plt.Circle((0.08, 0.08), 0.425, color='g', alpha=0.4)
ax.add_artist(circle1)
plt.scatter(x2, y2, c='y', s=100, alpha=0.5)

# %%
dataset = np.transpose(binary_dataset)

df = pd.DataFrame(dataset)
## shuffle a few times
df = df.sample(frac=1).reset_index(drop=True)
df = df.sample(frac=1).reset_index(drop=True)
df = df.sample(frac=1).reset_index(drop=True)
dataset = df.to_numpy()
df
# Out:
#             0         1
# 0    0.497450  0.164130
# 1    0.230468  0.484961
# 2    0.414478  0.443468
# 3    0.127505  0.000721
# 4    0.120217  0.053065
# ..        ...       ...
# 195  0.054738  0.303574
# 196  0.198038  0.062223
# 197  0.232620  0.345717
# 198  0.484604  0.337687
# 199  0.436162  0.415029
#
# [200 rows x 2 columns]

# %% [markdown]
# ## generate and validate labels

# %%
labels = []
ones = []
zeros = []
radiusSquared = math.pow(0.425, 2)

for i in range(len(dataset)):
    x0, y0 = dataset[i]
    locationRelativeToCircle = math.pow((x0 - 0.08), 2) + math.pow((y0 - 0.08), 2)

    if (locationRelativeToCircle > radiusSquared):
        labels.append(1)
        ones.append(i)
    else:
        labels.append(0)
        zeros.append(i)
        
fig = plt.figure(figsize=(16,16))
fig = plt.gcf()
ax = fig.gca()
circle1 = plt.Circle((0.08, 0.08), 0.425, color='g', alpha=0.1)
ax.add_artist(circle1)
for i,v in enumerate(labels):    
    if labels[i] == 1:
        plt.scatter(dataset[i][0], dataset[i][1], c='y', s=100, alpha=0.5)
    else:
        plt.scatter(dataset[i][0], dataset[i][1], c='g', s=100, alpha=0.5)

# %%
x_train = dataset[:160]
y_train = labels[:160]

x_val = dataset[-40:]
y_val = labels[-40:]
(x_train.shape, len(y_train)), (x_val.shape, len(y_val))
# Out:
# (((160, 2), 160), ((40, 2), 40))

# %% [markdown]
# ## For this problem I chose to use:
# - 1 hidden layer
# - relu as the activation for the input and hidden layers (because binary data: 0 or 1 as ouput)
# - sigmoid for activation in last layer (because sum of outputs does not to equal 1)
# - rmsprop (because its good for SGD)
# - binary_crossentropy for loss (because data is binary)

# %% [markdown]
# ## My model

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(2,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['acc'])

# %%
history = model.fit(x_train,
                    y_train,
                    epochs=100,
                    batch_size=16,
                    validation_data=(x_val, y_val))
# Out:
# Train on 160 samples, validate on 40 samples
# Epoch 1/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6625 - acc: 0.5000 - val_loss: 0.6291 - val_acc: 0.6500
# Epoch 2/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.6547 - acc: 0.5312 - val_loss: 0.6219 - val_acc: 0.6750
# Epoch 3/100
# 160/160 [==============================] - 0s 175us/step - loss: 0.6487 - acc: 0.5625 - val_loss: 0.6153 - val_acc: 0.6750
# Epoch 4/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.6426 - acc: 0.6063 - val_loss: 0.6072 - val_acc: 0.7000
# Epoch 5/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.6357 - acc: 0.6437 - val_loss: 0.5977 - val_acc: 0.7000
# Epoch 6/100
# 160/160 [==============================] - 0s 269us/step - loss: 0.6273 - acc: 0.6688 - val_loss: 0.5888 - val_acc: 0.7500
# Epoch 7/100
# 160/160 [==============================] - 0s 113us/step - loss: 0.6197 - acc: 0.6750 - val_loss: 0.5811 - val_acc: 0.7750
# Epoch 8/100
# 160/160 [==============================] - 0s 244us/step - loss: 0.6127 - acc: 0.6813 - val_loss: 0.5725 - val_acc: 0.7750
# Epoch 9/100
# 160/160 [==============================] - 0s 113us/step - loss: 0.6052 - acc: 0.7000 - val_loss: 0.5630 - val_acc: 0.8000
# Epoch 10/100
# 160/160 [==============================] - 0s 112us/step - loss: 0.5974 - acc: 0.7312 - val_loss: 0.5527 - val_acc: 0.8000
# Epoch 11/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.5901 - acc: 0.7188 - val_loss: 0.5455 - val_acc: 0.8250
# Epoch 12/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.5827 - acc: 0.7625 - val_loss: 0.5362 - val_acc: 0.8250
# Epoch 13/100
# 160/160 [==============================] - 0s 75us/step - loss: 0.5742 - acc: 0.7625 - val_loss: 0.5260 - val_acc: 0.8500
# Epoch 14/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.5657 - acc: 0.7812 - val_loss: 0.5158 - val_acc: 0.8500
# Epoch 15/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.5567 - acc: 0.7812 - val_loss: 0.5061 - val_acc: 0.8500
# Epoch 16/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.5474 - acc: 0.7812 - val_loss: 0.4964 - val_acc: 0.8500
# Epoch 17/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.5380 - acc: 0.8000 - val_loss: 0.4849 - val_acc: 0.8500
# Epoch 18/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.5279 - acc: 0.8313 - val_loss: 0.4732 - val_acc: 0.8500
# Epoch 19/100
# 160/160 [==============================] - 0s 125us/step - loss: 0.5178 - acc: 0.8187 - val_loss: 0.4631 - val_acc: 0.9000
# Epoch 20/100
# 160/160 [==============================] - 0s 75us/step - loss: 0.5073 - acc: 0.8313 - val_loss: 0.4515 - val_acc: 0.9250
# Epoch 21/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.4969 - acc: 0.8625 - val_loss: 0.4389 - val_acc: 0.9250
# Epoch 22/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.4860 - acc: 0.8562 - val_loss: 0.4270 - val_acc: 0.9500
# Epoch 23/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.4761 - acc: 0.8438 - val_loss: 0.4201 - val_acc: 0.9500
# Epoch 24/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.4665 - acc: 0.8875 - val_loss: 0.4074 - val_acc: 0.9500
# Epoch 25/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.4557 - acc: 0.8875 - val_loss: 0.3980 - val_acc: 0.9500
# Epoch 26/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.4452 - acc: 0.8875 - val_loss: 0.3861 - val_acc: 0.9500
# Epoch 27/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.4344 - acc: 0.9125 - val_loss: 0.3719 - val_acc: 0.9500
# Epoch 28/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.4245 - acc: 0.9000 - val_loss: 0.3618 - val_acc: 0.9500
# Epoch 29/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.4148 - acc: 0.9000 - val_loss: 0.3520 - val_acc: 0.9500
# Epoch 30/100
# 160/160 [==============================] - 0s 131us/step - loss: 0.4048 - acc: 0.9125 - val_loss: 0.3427 - val_acc: 0.9500
# Epoch 31/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.3943 - acc: 0.9125 - val_loss: 0.3352 - val_acc: 0.9500
# Epoch 32/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.3852 - acc: 0.9187 - val_loss: 0.3240 - val_acc: 0.9500
# Epoch 33/100
# 160/160 [==============================] - 0s 75us/step - loss: 0.3753 - acc: 0.9313 - val_loss: 0.3138 - val_acc: 0.9500
# Epoch 34/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.3643 - acc: 0.9187 - val_loss: 0.3062 - val_acc: 0.9500
# Epoch 35/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.3544 - acc: 0.9437 - val_loss: 0.2930 - val_acc: 0.9500
# Epoch 36/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.3439 - acc: 0.9375 - val_loss: 0.2819 - val_acc: 0.9500
# Epoch 37/100
# 160/160 [==============================] - 0s 137us/step - loss: 0.3349 - acc: 0.9313 - val_loss: 0.2746 - val_acc: 0.9500
# Epoch 38/100
# 160/160 [==============================] - 0s 169us/step - loss: 0.3265 - acc: 0.9437 - val_loss: 0.2670 - val_acc: 0.9750
# Epoch 39/100
# 160/160 [==============================] - 0s 181us/step - loss: 0.3168 - acc: 0.9437 - val_loss: 0.2556 - val_acc: 0.9500
# Epoch 40/100
# 160/160 [==============================] - 0s 131us/step - loss: 0.3094 - acc: 0.9437 - val_loss: 0.2474 - val_acc: 0.9750
# Epoch 41/100
# 160/160 [==============================] - 0s 212us/step - loss: 0.3015 - acc: 0.9437 - val_loss: 0.2392 - val_acc: 0.9750
# Epoch 42/100
# 160/160 [==============================] - 0s 162us/step - loss: 0.2918 - acc: 0.9437 - val_loss: 0.2296 - val_acc: 0.9750
# Epoch 43/100
# 160/160 [==============================] - 0s 181us/step - loss: 0.2837 - acc: 0.9437 - val_loss: 0.2195 - val_acc: 0.9750
# Epoch 44/100
# 160/160 [==============================] - 0s 200us/step - loss: 0.2751 - acc: 0.9437 - val_loss: 0.2135 - val_acc: 1.0000
# Epoch 45/100
# 160/160 [==============================] - 0s 131us/step - loss: 0.2681 - acc: 0.9437 - val_loss: 0.2067 - val_acc: 1.0000
# Epoch 46/100
# 160/160 [==============================] - 0s 175us/step - loss: 0.2604 - acc: 0.9437 - val_loss: 0.1995 - val_acc: 1.0000
# Epoch 47/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.2534 - acc: 0.9437 - val_loss: 0.1947 - val_acc: 1.0000
# Epoch 48/100
# 160/160 [==============================] - 0s 125us/step - loss: 0.2454 - acc: 0.9437 - val_loss: 0.1865 - val_acc: 1.0000
# Epoch 49/100
# 160/160 [==============================] - 0s 69us/step - loss: 0.2389 - acc: 0.9500 - val_loss: 0.1761 - val_acc: 1.0000
# Epoch 50/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.2321 - acc: 0.9437 - val_loss: 0.1753 - val_acc: 1.0000
# Epoch 51/100
# 160/160 [==============================] - 0s 88us/step - loss: 0.2281 - acc: 0.9437 - val_loss: 0.1678 - val_acc: 1.0000
# Epoch 52/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.2212 - acc: 0.9500 - val_loss: 0.1619 - val_acc: 1.0000
# Epoch 53/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.2167 - acc: 0.9500 - val_loss: 0.1555 - val_acc: 1.0000
# Epoch 54/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.2109 - acc: 0.9500 - val_loss: 0.1516 - val_acc: 1.0000
# Epoch 55/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.2066 - acc: 0.9500 - val_loss: 0.1500 - val_acc: 1.0000
# Epoch 56/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.2024 - acc: 0.9500 - val_loss: 0.1415 - val_acc: 1.0000
# Epoch 57/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1975 - acc: 0.9500 - val_loss: 0.1357 - val_acc: 1.0000
# Epoch 58/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.1937 - acc: 0.9563 - val_loss: 0.1298 - val_acc: 1.0000
# Epoch 59/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1904 - acc: 0.9500 - val_loss: 0.1255 - val_acc: 1.0000
# Epoch 60/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.1881 - acc: 0.9500 - val_loss: 0.1254 - val_acc: 1.0000
# Epoch 61/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.1836 - acc: 0.9500 - val_loss: 0.1213 - val_acc: 1.0000
# Epoch 62/100
# 160/160 [==============================] - 0s 69us/step - loss: 0.1814 - acc: 0.9437 - val_loss: 0.1196 - val_acc: 1.0000
# Epoch 63/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1778 - acc: 0.9500 - val_loss: 0.1200 - val_acc: 1.0000
# Epoch 64/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1752 - acc: 0.9500 - val_loss: 0.1178 - val_acc: 1.0000
# Epoch 65/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1726 - acc: 0.9500 - val_loss: 0.1137 - val_acc: 1.0000
# Epoch 66/100
# 160/160 [==============================] - 0s 137us/step - loss: 0.1692 - acc: 0.9500 - val_loss: 0.1100 - val_acc: 1.0000
# Epoch 67/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.1683 - acc: 0.9500 - val_loss: 0.1056 - val_acc: 1.0000
# Epoch 68/100
# 160/160 [==============================] - 0s 113us/step - loss: 0.1645 - acc: 0.9500 - val_loss: 0.1053 - val_acc: 1.0000
# Epoch 69/100
# 160/160 [==============================] - 0s 156us/step - loss: 0.1643 - acc: 0.9500 - val_loss: 0.1023 - val_acc: 1.0000
# Epoch 70/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.1602 - acc: 0.9500 - val_loss: 0.0987 - val_acc: 1.0000
# Epoch 71/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.1595 - acc: 0.9500 - val_loss: 0.1005 - val_acc: 1.0000
# Epoch 72/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1582 - acc: 0.9563 - val_loss: 0.0975 - val_acc: 1.0000
# Epoch 73/100
# 160/160 [==============================] - 0s 75us/step - loss: 0.1553 - acc: 0.9563 - val_loss: 0.0955 - val_acc: 1.0000
# Epoch 74/100
# 160/160 [==============================] - 0s 106us/step - loss: 0.1547 - acc: 0.9500 - val_loss: 0.0929 - val_acc: 1.0000
# Epoch 75/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.1516 - acc: 0.9500 - val_loss: 0.0946 - val_acc: 1.0000
# Epoch 76/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.1506 - acc: 0.9563 - val_loss: 0.0907 - val_acc: 1.0000
# Epoch 77/100
# 160/160 [==============================] - 0s 69us/step - loss: 0.1497 - acc: 0.9500 - val_loss: 0.0895 - val_acc: 1.0000
# Epoch 78/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1468 - acc: 0.9625 - val_loss: 0.0881 - val_acc: 1.0000
# Epoch 79/100
# 160/160 [==============================] - 0s 87us/step - loss: 0.1455 - acc: 0.9625 - val_loss: 0.0859 - val_acc: 1.0000
# Epoch 80/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1440 - acc: 0.9500 - val_loss: 0.0862 - val_acc: 1.0000
# Epoch 81/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1424 - acc: 0.9563 - val_loss: 0.0812 - val_acc: 1.0000
# Epoch 82/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.1417 - acc: 0.9625 - val_loss: 0.0759 - val_acc: 1.0000
# Epoch 83/100
# 160/160 [==============================] - ETA: 0s - loss: 0.2726 - acc: 0.875 - 0s 87us/step - loss: 0.1405 - acc: 0.9563 - val_loss: 0.0758 - val_acc: 1.0000
# Epoch 84/100
# 160/160 [==============================] - 0s 75us/step - loss: 0.1394 - acc: 0.9563 - val_loss: 0.0746 - val_acc: 1.0000
# Epoch 85/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1371 - acc: 0.9563 - val_loss: 0.0756 - val_acc: 1.0000
# Epoch 86/100
# 160/160 [==============================] - 0s 131us/step - loss: 0.1358 - acc: 0.9688 - val_loss: 0.0708 - val_acc: 1.0000
# Epoch 87/100
# 160/160 [==============================] - 0s 125us/step - loss: 0.1375 - acc: 0.9563 - val_loss: 0.0702 - val_acc: 1.0000
# Epoch 88/100
# 160/160 [==============================] - 0s 112us/step - loss: 0.1343 - acc: 0.9563 - val_loss: 0.0732 - val_acc: 1.0000
# Epoch 89/100
# 160/160 [==============================] - 0s 138us/step - loss: 0.1332 - acc: 0.9625 - val_loss: 0.0691 - val_acc: 1.0000
# Epoch 90/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.1327 - acc: 0.9625 - val_loss: 0.0682 - val_acc: 1.0000
# Epoch 91/100
# 160/160 [==============================] - 0s 187us/step - loss: 0.1310 - acc: 0.9625 - val_loss: 0.0639 - val_acc: 1.0000
# Epoch 92/100
# 160/160 [==============================] - 0s 156us/step - loss: 0.1296 - acc: 0.9563 - val_loss: 0.0724 - val_acc: 1.0000
# Epoch 93/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.1302 - acc: 0.9750 - val_loss: 0.0639 - val_acc: 1.0000
# Epoch 94/100
# 160/160 [==============================] - 0s 125us/step - loss: 0.1303 - acc: 0.9625 - val_loss: 0.0662 - val_acc: 1.0000
# Epoch 95/100
# 160/160 [==============================] - 0s 94us/step - loss: 0.1282 - acc: 0.9688 - val_loss: 0.0639 - val_acc: 1.0000
# Epoch 96/100
# 160/160 [==============================] - 0s 125us/step - loss: 0.1294 - acc: 0.9625 - val_loss: 0.0643 - val_acc: 1.0000
# Epoch 97/100
# 160/160 [==============================] - 0s 175us/step - loss: 0.1269 - acc: 0.9688 - val_loss: 0.0627 - val_acc: 1.0000
# Epoch 98/100
# 160/160 [==============================] - 0s 100us/step - loss: 0.1272 - acc: 0.9625 - val_loss: 0.0599 - val_acc: 1.0000
# Epoch 99/100
# 160/160 [==============================] - 0s 81us/step - loss: 0.1247 - acc: 0.9625 - val_loss: 0.0630 - val_acc: 1.0000
# Epoch 100/100
# 160/160 [==============================] - 0s 112us/step - loss: 0.1267 - acc: 0.9625 - val_loss: 0.0622 - val_acc: 1.0000

# %% [markdown]
# ## Evaluating the model

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
acc = history_dict['acc']
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(16, 10))
plt.plot(epochs, loss_values, 'r', label='Training loss')
plt.plot(epochs, val_loss_values, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']

plt.figure(figsize=(16, 10))
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'g', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Testing

# %%
x_test, y_test = [], []
x1_test = abs(np.random.rand(5000))
y1_test = abs(np.random.rand(5000))

x2_test, y2_test = [], []
for i, v in enumerate(x1_test):
    if x1_test[i] <= 0.5 and y1_test[i] <= 0.5 and len(x2_test) < 500:
        x2_test.append(x1_test[i])
        y2_test.append(y1_test[i])
x_test.append(x2_test)
x_test.append(y2_test)
x_test = np.transpose(x_test)

## dont need to shuffle because it is a random set of points

for i in range(len(x_test)):
    x0, y0 = x_test[i]
    locationRelativeToCircle = math.pow((x0 - 0.08), 2) + math.pow((y0 - 0.08), 2)
    if (locationRelativeToCircle > radiusSquared):
        y_test.append(1)
    else:
        y_test.append(0)
        
plt.figure(figsize=(16,16))
for i,v in enumerate(y_test):
    if y_test[i] == 1:
        plt.scatter(x_test[i][0], x_test[i][1], c='y', s=200, alpha=0.3)
        plt.scatter(x_test[i][0], x_test[i][1], s=35, alpha=0.9)
    else:
        plt.scatter(x_test[i][0], x_test[i][1], c='g', s=200, alpha=0.3)
        plt.scatter(x_test[i][0], x_test[i][1], s=35, alpha=0.9)

# %%
results = model.evaluate(x_test, y_test)
results, model.metrics_names
# Out:
# 500/500 [==============================] - 0s 26us/step
# ([0.20165203213691713, 0.9059999990463257], ['loss', 'acc'])

# %% [markdown]
# # 😰 😱 🥵 🥶 🤧 🥴
